# %% [markdown]
# ## 1.1 Load Department of Education (DOE) and CEDA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Department of Education data
DOE_data = pd.read_excel('/content/drive/My Drive/Candidate Platforms and Endorsements/Three files discussed 10-18-23/Base_File_from_State_Dept_Ed.xls')
DOE_data.head()
# Out:
#     County  Year                  DOCType         District  Status  \
# 0  Alameda  1996  Unified School District  Alameda Unified  Active
# 1  Alameda  1997  Unified School District  Alameda Unified  Active
# 2  Alameda  1998  Unified School District  Alameda Unified  Active
# 3  Alameda  1999  Unified School District  Alameda Unified  Active
# 4  Alameda  2000  Unified School District  Alameda Unified  Active
#
#                          WebSite    cds7   leaid  DOC
# 0  http://www.alamedaunified.org  161119  601770   54
# 1  http://www.alamedaunified.org  161119  601770   54
# 2  http://www.alamedaunified.org  161119  601770   54
# 3  http://www.alamedaunified.org  161119  601770   54
# 4  http://www.alamedaunified.org  161119  601770   54

# %%
# Load truncated unique district-year CEDA elections
CEDA_data = pd.read_excel('/content/drive/My Drive/Candidate Platforms and Endorsements/Three files discussed 10-18-23/All unique district-year elections from CEDA.xlsx')
CEDA_data.head()
# Out:
#   CNTYNAME  YEAR                       PLACE election_type  countyboard  coe  \
# 0  ALAMEDA  1996  ALAMEDA BOARD OF EDUCATION       Regular          NaN  NaN
# 1  ALAMEDA  2000        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
# 2  ALAMEDA  2004        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
# 3  ALAMEDA  2006        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
# 4  ALAMEDA  2010        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
#
#    leaid
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
CEDA_data = CEDA_data[(CEDA_data['countyboard'] != 1) & (CEDA_data['coe'] != 1)]
CEDA_data.drop(['countyboard', 'coe'], axis=1)
# Out:
#      CNTYNAME  YEAR                         PLACE election_type  leaid
# 0     ALAMEDA  1996    ALAMEDA BOARD OF EDUCATION       Regular    NaN
# 1     ALAMEDA  2000          ALAMEDA CITY UNIFIED       Regular    NaN
# 2     ALAMEDA  2004          ALAMEDA CITY UNIFIED       Regular    NaN
# 3     ALAMEDA  2006          ALAMEDA CITY UNIFIED       Regular    NaN
# 4     ALAMEDA  2010          ALAMEDA CITY UNIFIED       Regular    NaN
# ...       ...   ...                           ...           ...    ...
# 8357     YUBA  2012          WHEATLAND UNION HIGH       Regular    NaN
# 8358     YUBA  2014          WHEATLAND UNION HIGH       Regular    NaN
# 8359     YUBA  2016          WHEATLAND UNION HIGH       Regular    NaN
# 8360     YUBA  2020          WHEATLAND UNION HIGH       Regular    NaN
# 8361     YUBA  1998  YUBA CO. OFFICE OF EDUCATION       Regular    NaN
#
# [7873 rows x 5 columns]

# %%
# Standardize column names
CEDA_data.columns = [x.lower() for x in CEDA_data.columns]
DOE_data.columns = [x.lower() for x in DOE_data.columns]

# Standardize strings
CEDA_data['cntyname'] = CEDA_data['cntyname'].str.lower()
CEDA_data['place'] = CEDA_data['place'].str.lower()

DOE_data['county'] = DOE_data['county'].str.lower()
DOE_data['district'] = DOE_data['district'].str.lower()

# %%
# Check county lists between DOE/CEDA, conclude identical
ceda_counties = CEDA_data['cntyname'].unique()
doe_counties = DOE_data['county'].unique()

set1 = set(ceda_counties)
set2 = set(doe_counties)

unique_elements_in_array1 = set1.difference(set2)
unique_elements_in_array2 = set2.difference(set1)

ceda_counties_diff = list(unique_elements_in_array1)
doe_counties_diff = list(unique_elements_in_array2)

print(ceda_counties_diff)
print(doe_counties_diff)
# Out:
# []
# []

# %% [markdown]
# ## 1.2 Match from DOE to CEDA

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Get word counts in all names
appended = ''

for i, row in DOE_data.iterrows():
  district = row['district']
  appended = appended + ' ' + district

counts = {}

words = appended.split()
uniq_words = set(words)
for word in uniq_words:
  counts[word] = appended.count(word)

# Get words to remove from keywords
sorted_counts = dict(sorted(counts.items(), key=lambda item: item[1], reverse=True))
filler = {'elementary', 'union', 'unified', 'high', 'joint', 'los', 'valley', 'san', 'city', 'beach'}

# %%
sorted_counts
# Out:
# {'le': 22977,
#  'el': 19602,
#  'elem': 16956,
#  'eleme': 16902,
#  'elemen': 16821,
#  'element': 16794,
#  'elementa': 16767,
#  'elementar': 16740,
#  'elementary': 16659,
#  'union': 10827,
#  'unified': 9450,
#  'la': 3915,
#  'hig': 3267,
#  'high': 3240,
#  'joint': 2835,
#  'val': 2241,
#  'valle': 2133,
#  'valley': 2025,
#  'san': 1944,
#  '-': 1755,
#  'city': 1350,
#  'lake': 702,
#  'di': 675,
#  'mar': 540,
#  'oak': 540,
#  'santa': 540,
#  'los': 486,
#  'del': 432,
#  'fe': 432,
#  'side': 432,
#  'river': 405,
#  'creek': 405,
#  'view': 378,
#  'the': 378,
#  'hill': 351,
#  'south': 351,
#  'west': 351,
#  'ana': 351,
#  'mount': 324,
#  'park': 324,
#  'oro': 297,
#  'beach': 297,
#  'spring': 297,
#  'old': 297,
#  'grove': 297,
#  'new': 270,
#  'mountain': 270,
#  'bar': 270,
#  'monte': 243,
#  'pleasant': 243,
#  'big': 243,
#  'county': 243,
#  'hart': 243,
#  'north': 216,
#  'sun': 216,
#  'red': 216,
#  'hills': 189,
#  'harte': 189,
#  'mad': 189,
#  'palo': 189,
#  'gold': 189,
#  'fort': 189,
#  'ridge': 189,
#  'rio': 189,
#  'vista': 189,
#  'center': 189,
#  'pine': 189,
#  'las': 189,
#  'sierra': 189,
#  'springs': 189,
#  'central': 162,
#  'washington': 162,
#  'east': 162,
#  'fall': 162,
#  'jt.': 162,
#  'fork': 162,
#  'king': 162,
#  'rock': 162,
#  'pacific': 162,
#  'green': 135,
#  'shasta': 135,
#  'willow': 135,
#  'juan': 135,
#  'charter': 135,
#  'trinity': 135,
#  'kings': 135,
#  'camp': 135,
#  'lakes': 135,
#  'delta': 135,
#  'verde': 135,
#  'two': 108,
#  'ross': 108,
#  'palos': 108,
#  'bluff': 108,
#  'jefferson': 108,
#  'mesa': 108,
#  'paso': 108,
#  'kerman': 108,
#  'bay': 108,
#  'plum': 108,
#  'golden': 108,
#  'of': 108,
#  'lakeside': 108,
#  'live': 108,
#  'mill': 108,
#  'ione': 108,
#  'eureka': 108,
#  'rand': 108,
#  'loma': 108,
#  'merced': 108,
#  'flat': 108,
#  'orland': 108,
#  'whittier': 108,
#  'placer': 108,
#  'linda': 108,
#  'hope': 108,
#  'alto': 108,
#  'glen': 108,
#  'chawanakee': 81,
#  'antelope': 81,
#  'rivers': 81,
#  'monterey': 81,
#  'lucerne': 81,
#  'robles': 81,
#  'alum': 81,
#  'ferndale': 81,
#  'plumas': 81,
#  'buena': 81,
#  'turlock': 81,
#  'mt.': 81,
#  'healdsburg': 81,
#  'compton': 81,
#  'moorpark': 81,
#  'dinuba': 81,
#  'caruthers': 81,
#  'long': 81,
#  'pioneer': 81,
#  'ranch': 81,
#  'elsinore': 81,
#  'coachella': 81,
#  'grant': 81,
#  'ocean': 81,
#  'woodlake': 81,
#  'hughson': 81,
#  'soledad': 81,
#  'dos': 81,
#  'empire': 81,
#  'scott': 81,
#  'upper': 81,
#  'gridley': 81,
#  'coast': 81,
#  'happy': 81,
#  'junction': 81,
#  'canyon': 81,
#  'porterville': 81,
#  'maria': 81,
#  'barbara': 81,
#  'walnut': 81,
#  'alta': 81,
#  'tracy': 81,
#  'southern': 81,
#  'grand': 81,
#  'elk': 81,
#  'fortuna': 81,
#  'alhambra': 81,
#  'peninsula': 81,
#  'paula': 81,
#  'oakdale': 81,
#  'hamilton': 81,
#  'bishop': 81,
#  'exeter': 81,
#  'riverdale': 81,
#  'kern': 81,
#  'butte': 81,
#  'twin': 81,
#  'bass': 81,
#  'gonzales': 81,
#  'liberty': 81,
#  'tule': 81,
#  'mammoth': 54,
#  'desert': 54,
#  'indian': 54,
#  'lammersville': 54,
#  'galt': 54,
#  'vallecito': 54,
#  'petaluma': 54,
#  'westside': 54,
#  'rowland': 54,
#  'dunsmuir': 54,
#  'bear': 54,
#  'apple': 54,
#  'black': 54,
#  'dairyland': 54,
#  'run': 54,
#  'lincoln': 54,
#  'richland': 54,
#  'julian': 54,
#  'gustine': 54,
#  'evergreen': 54,
#  'salinas': 54,
#  'montebello': 54,
#  'deltas': 54,
#  'feather': 54,
#  'buckeye': 54,
#  'yosemite': 54,
#  'farmersville': 54,
#  'tahoe': 54,
#  'covina': 54,
#  'mine': 54,
#  'dulce': 54,
#  'francisco': 54,
#  'kingsburg': 54,
#  'wasco': 54,
#  'wright': 54,
#  'rafael': 54,
#  'tejon': 54,
#  'mendota': 54,
#  'tustin': 54,
#  'falls': 54,
#  'fremont': 54,
#  'columbia': 54,
#  'lemoore': 54,
#  'community': 54,
#  'sands': 54,
#  'victor': 54,
#  'redondo': 54,
#  'silver': 54,
#  'banta': 54,
#  'sur': 54,
#  'cruz': 54,
#  'mattole': 54,
#  'chowchilla': 54,
#  'murrieta': 54,
#  'fullerton': 54,
#  'brawley': 54,
#  'cotati-rohnert': 54,
#  'arena': 54,
#  'little': 54,
#  'sunol': 54,
#  'upland': 54,
#  'campbell': 54,
#  'fallbrook': 54,
#  'scotts': 54,
#  'baker': 54,
#  'burbank': 54,
#  'humboldt': 54,
#  'saratoga': 54,
#  'waterford': 54,
#  'roseville': 54,
#  'bella': 54,
#  'mcfarland': 54,
#  'escondido': 54,
#  'temple': 54,
#  'franklin': 54,
#  'amador': 54,
#  'flat-groveland': 54,
#  'modesto': 54,
#  'plains': 54,
#  'joaquin': 54,
#  'cuyama': 54,
#  'pleasanton': 54,
#  'temecula': 54,
#  'strathmore': 54,
#  'yorba': 54,
#  'john': 54,
#  'firebaugh': 54,
#  'bonsall': 54,
#  'bravo': 54,
#  'castle': 54,
#  'nevada': 54,
#  'bonita': 54,
#  'knights': 54,
#  'delano': 54,
#  'perris': 54,
#  'marin': 54,
#  'tulare': 54,
#  'island': 54,
#  'lassen': 54,
#  'whisman': 54,
#  'fresno': 54,
#  'madera': 54,
#  'pauma': 54,
#  'delhi': 54,
#  'taft': 54,
#  'tulelake': 54,
#  'palm': 54,
#  'yreka': 54,
#  'hanford': 54,
#  'ferry': 54,
#  'manhattan': 54,
#  'redwood': 54,
#  'holt': 54,
#  'tranquillity': 54,
#  'mateo': 54,
#  'greeley': 54,
#  'fairfax': 54,
#  'sacramento': 54,
#  'weaver': 54,
#  'point': 54,
#  'panama': 54,
#  'gatos': 54,
#  'ramon': 54,
#  'laguna': 54,
#  'paradise': 54,
#  'thermal': 54,
#  'kit': 54,
#  'pasadena': 54,
#  'windsor': 54,
#  'etna': 54,
#  'hesperia': 54,
#  'enterprise': 54,
#  'sequoia': 54,
#  'sonora': 54,
#  'oroville': 54,
#  'rocklin': 54,
#  'lorenzo': 54,
#  'orange': 54,
#  'clara': 54,
#  'gabriel': 54,
#  'greenfield': 54,
#  'pasqual': 54,
#  'altos': 54,
#  'puente': 54,
#  'alpine': 54,
#  'mark': 54,
#  'huntington': 54,
#  'corning': 54,
#  'summerville': 54,
#  'cambria': 54,
#  'anaheim': 54,
#  'magnolia': 54,
#  'rancho': 54,
#  'twain': 54,
#  'warner': 54,
#  'maple': 54,
#  'sonoma': 54,
#  'round': 54,
#  'lagunita': 54,
#  'wheatland': 54,
#  'anderson': 54,
#  'rosa': 54,
#  'klamath': 54,
#  'riverbank': 54,
#  'modoc': 54,
#  'natomas': 54,
#  'oxnard': 54,
#  'william': 54,
#  'wiseburn': 54,
#  'reed': 54,
#  'prairie': 27,
#  'armona': 27,
#  'butteville': 27,
#  'needles': 27,
#  'bennett': 27,
#  'acalanes': 27,
#  'pinos': 27,
#  'reeds': 27,
#  'arcadia': 27,
#  'chino': 27,
#  'hollister': 27,
#  'robla': 27,
#  'westmorland': 27,
#  'hillsborough': 27,
#  'konocti': 27,
#  'calistoga': 27,
#  'aromas': 27,
#  'soulsbyville': 27,
#  'colony': 27,
#  'nicolaus': 27,
#  'shoreline': 27,
#  'baldy': 27,
#  'waugh': 27,
#  'bellflower': 27,
#  'flores': 27,
#  'spencer': 27,
#  'panama-buena': 27,
#  'ready': 27,
#  'piedmont': 27,
#  'loleta': 27,
#  'lakeport': 27,
#  'raisin': 27,
#  'dell': 27,
#  'newcastle': 27,
#  'olympia': 27,
#  'montague': 27,
#  'sawyers': 27,
#  'sutter': 27,
#  'pomona': 27,
#  'diggings': 27,
#  'grenada': 27,
#  'colton': 27,
#  'willowbrook': 27,
#  'cascade': 27,
#  'nuestro': 27,
#  'sulphur': 27,
#  'burnt': 27,
#  'baldwin': 27,
#  'salmon': 27,
#  'hughes-elizabeth': 27,
#  'buellton': 27,
#  'maria-bonita': 27,
#  'view-los': 27,
#  'gulch-whiskeytown': 27,
#  'kelseyville': 27,
#  'woodside': 27,
#  'cinnabar': 27,
#  'honda-pescadero': 27,
#  'paramount': 27,
#  'surprise': 27,
#  'bonny': 27,
#  'sage': 27,
#  'vallejo': 27,
#  'plaza': 27,
#  'grizzly': 27,
#  'meadows': 27,
#  'valley-poso': 27,
#  'benton': 27,
#  'citrus': 27,
#  'knightsen': 27,
#  'richmond': 27,
#  'browns': 27,
#  'vining': 27,
#  'anselmo': 27,
#  'nuview': 27,
#  'seiad': 27,
#  'herndon': 27,
#  'westwood': 27,
#  'keppel': 27,
#  'sebastopol': 27,
#  'prieta': 27,
#  'albany': 27,
#  'tres': 27,
#  'antonio': 27,
#  'platina': 27,
#  'esparto': 27,
#  'ono,': 27,
#  'montecito': 27,
#  'hudson': 27,
#  'jerusalem': 27,
#  'millbrae': 27,
#  'rockford': 27,
#  'coastal': 27,
#  'salida': 27,
#  'doon': 27,
#  'newman-gustine': 27,
#  'corcoran': 27,
#  'helendale': 27,
#  'alvord': 27,
#  'contra': 27,
#  'sierra-plumas': 27,
#  'mckinleyville': 27,
#  'canada': 27,
#  'terra': 27,
#  'wasuma': 27,
#  'semitropic': 27,
#  'jose': 27,
#  'hopeton': 27,
#  'penn': 27,
#  'elkins': 27,
#  'alameda': 27,
#  'modoc-tulelake': 27,
#  'segundo': 27,
#  'pope': 27,
#  'shafter': 27,
#  's.': 27,
#  'inglewood': 27,
#  'loomis': 27,
#  'selma': 27,
#  'torrance': 27,
#  'byron': 27,
#  'banos': 27,
#  'hilmar': 27,
#  'elverta': 27,
#  'marino': 27,
#  'firebaugh-las': 27,
#  'lagoon': 27,
#  'colfax': 27,
#  'encinitas': 27,
#  'bellevue': 27,
#  'mendocino': 27,
#  'bakersfield': 27,
#  'hoaglin-zenia': 27,
#  'cantua': 27,
#  'hickman': 27,
#  'chico': 27,
#  'teague': 27,
#  'wilmar': 27,
#  'spreckels': 27,
#  'trabuco': 27,
#  'sundale': 27,
#  'lemon': 27,
#  'guerneville': 27,
#  'traver': 27,
#  'durham': 27,
#  'cherokee': 27,
#  'blake': 27,
#  'curtis': 27,
#  'pacifica': 27,
#  'auburn': 27,
#  'cutler-orosi': 27,
#  'mission': 27,
#  'beverly': 27,
#  'newman-crows': 27,
#  'newark': 27,
#  'solvang': 27,
#  'newhall': 27,
#  'alamos': 27,
#  'seeley': 27,
#  'saint': 27,
#  'carlsbad': 27,
#  'lindsay': 27,
#  'waukena': 27,
#  'mccabe': 27,
#  'vineland': 27,
#  'fillmore': 27,
#  'callahan-east': 27,
#  'shiloh': 27,
#  'chaffey': 27,
#  'thermalito': 27,
#  'lamont': 27,
#  'vacaville': 27,
#  'bridgeport': 27,
#  'coronado': 27,
#  'ynez': 27,
#  'woodland': 27,
#  'travis': 27,
#  'emery': 27,
#  'leandro': 27,
#  'novato': 27,
#  'berryessa': 27,
#  'cold': 27,
#  'camino': 27,
#  'rosemead': 27,
#  'winton': 27,
#  'lowell': 27,
#  'eastside': 27,
#  'laton': 27,
#  'lapuente': 27,
#  'lennox': 27,
#  'olivos': 27,
#  'hyampom': 27,
#  'scotia': 27,
#  'mckinley-roosevelt': 27,
#  'leggett': 27,
#  'chicago': 27,
#  'ravenswood': 27,
#  'carpinteria': 27,
#  'calexico': 27,
#  'nicasio': 27,
#  'alview-dairyland': 27,
#  'ardo': 27,
#  'cuddeback': 27,
#  'cupertino': 27,
#  'lee': 27,
#  'escalon': 27,
#  'azusa': 27,
#  'mecca': 27,
#  'marysville': 27,
#  'conejo': 27,
#  'davis': 27,
#  'schools': 27,
#  'dorado': 27,
#  'capistrano': 27,
#  'parlier': 27,
#  'landing': 27,
#  'guadalupe': 27,
#  'virgenes': 27,
#  'sweetwater': 27,
#  'garvey': 27,
#  'seal': 27,
#  'solana': 27,
#  'hot': 27,
#  'pittsburg': 27,
#  'whitmore': 27,
#  'snelling-merced': 27,
#  'minarets': 27,
#  'rosedale': 27,
#  'oakland': 27,
#  'vallecitos': 27,
#  'orcutt': 27,
#  'dry': 27,
#  'springville': 27,
#  'linns': 27,
#  'phelan': 27,
#  'lafayette': 27,
#  'oasis': 27,
#  'morongo': 27,
#  'blochman': 27,
#  'acton-agua': 27,
#  'burrel': 27,
#  'bridgeville': 27,
#  'johnstonville': 27,
#  'dorris': 27,
#  'piner-olivet': 27,
#  'foresthill': 27,
#  'westminster': 27,
#  'riverside': 27,
#  'mother': 27,
#  'georgetown': 27,
#  'manteca': 27,
#  'portola': 27,
#  'grange': 27,
#  'madison': 27,
#  'arcata': 27,
#  'gravenstein': 27,
#  'plainsburg': 27,
#  'fountain': 27,
#  'patterson': 27,
#  'willows': 27,
#  'monica-malibu': 27,
#  'alisal': 27,
#  'national': 27,
#  'house': 27,
#  'ophir': 27,
#  'chinese': 27,
#  'jamul-dulzura': 27,
#  'hayward': 27,
#  'fruitvale': 27,
#  'cajon': 27,
#  'oceanside': 27,
#  'belleview': 27,
#  'brisbane': 27,
#  'potter': 27,
#  'douglas': 27,
#  'chualar': 27,
#  'cucamonga': 27,
#  'poway': 27,
#  'atwater': 27,
#  'earlimart': 27,
#  'linden': 27,
#  'bangor': 27,
#  'oakhurst': 27,
#  'center-pauma': 27,
#  'norris': 27,
#  'marcum-illinois': 27,
#  'home': 27,
#  'mono': 27,
#  'habra': 27,
#  'norwalk-la': 27,
#  'cypress': 27,
#  'mccloud': 27,
#  'benicia': 27,
#  'lone': 27,
#  'basin': 27,
#  'maxwell': 27,
#  'delphic': 27,
#  'tahoe-truckee': 27,
#  'columbine': 27,
#  'calaveras': 27,
#  'coffee': 27,
#  'biola-pershing': 27,
#  'manton': 27,
#  'ballard': 27,
#  'horicon': 27,
#  'garfield': 27,
#  'world': 27,
#  'giorgio': 27,
#  'casmalia': 27,
#  'mesa-spring': 27,
#  'murray': 27,
#  'wrightwood': 27,
#  'colusa': 27,
#  'alta-dutch': 27,
#  'simi': 27,
#  'rohnerville': 27,
#  'stockton': 27,
#  'houghton-kearney': 27,
#  'buttonwillow': 27,
#  'arcohe': 27,
#  'richfield': 27,
#  'emigrant': 27,
#  'rincon': 27,
#  'panoche': 27,
#  'french': 27,
#  'diego': 27,
#  'northern': 27,
#  'eastern': 27,
#  'siskiyou': 27,
#  'nietos': 27,
#  'college': 27,
#  'janesville': 27,
#  'ojai': 27,
#  'redding': 27,
#  'owens': 27,
#  'downey': 27,
#  'winters': 27,
#  'cambrian': 27,
#  'cloverdale': 27,
#  'fontana': 27,
#  'rescue': 27,
#  'cabrillo': 27,
#  'bruno': 27,
#  'southside': 27,
#  'planada': 27,
#  'coalinga-huron': 27,
#  'mulberry': 27,
#  'ravendale-termo': 27,
#  'cayucos': 27,
#  'castaic': 27,
#  'claremont': 27,
#  'jacinto': 27,
#  'soquel': 27,
#  'cienega': 27,
#  'livermore': 27,
#  'lindo': 27,
#  'ontario-montclair': 27,
#  'belmont-redwood': 27,
#  'sylvan': 27,
#  'garden': 27,
#  'pixley': 27,
#  'hemet': 27,
#  'miller': 27,
#  'adobe': 27,
#  'nido': 27,
#  'alpaugh': 27,
#  'romoland': 27,
#  'calipatria': 27,
#  'manzanita': 27,
#  'death': 27,
#  'heights': 27,
#  'oaks': 27,
#  'kernville': 27,
#  'marcos': 27,
#  'ysidro': 27,
#  'friant': 27,
#  'etiwanda': 27,
#  'biggs': 27,
#  'beaumont': 27,
#  'rindge': 27,
#  'mojave': 27,
#  'rim': 27,
#  'moreland': 27,
#  'weaverville': 27,
#  'northside': 27,
#  'corral': 27,
#  'berkeley': 27,
#  'ripon': 27,
#  'mupu': 27,
#  'wilsona': 27,
#  'lompoc': 27,
#  'yuba': 27,
#  'molinos': 27,
#  'reef-sunset': 27,
#  'saucelito': 27,
#  'allensworth': 27,
#  'lynwood': 27,
#  'capay': 27,
#  'weed': 27,
#  'winship-robbins': 27,
#  'jamestown': 27,
#  'mateo-foster': 27,
#  'gap': 27,
#  'lawndale': 27,
#  'freshwater': 27,
#  'hermosa': 27,
#  'bitterwater-tully': 27,
#  'rialto': 27,
#  'ackerman': 27,
#  'benito': 27,
#  'latrobe': 27,
#  'kashia': 27,
#  'mineral': 27,
#  'raymond-knowles': 27,
#  'western': 27,
#  'diablo': 27,
#  'middletown': 27,
#  'blue': 27,
#  'atascadero': 27,
#  'kenwood': 27,
#  'beardsley': 27,
#  'kerman-floyd': 27,
#  'lagunitas': 27,
#  'sunnyside': 27,
#  'education': 27,
#  'sanger': 27,
#  'borrego': 27,
#  'edison': 27,
#  'lost': 27,
#  'grossmont': 27,
#  'burton': 27,
#  'millville': 27,
#  'folsom-cordova': 27,
#  'forestville': 27,
#  'divide': 27,
#  'gateway': 27,
#  'tipton': 27,
#  'monrovia': 27,
#  'hueneme': 27,
#  'river-hardwick': 27,
#  'palermo': 27,
#  'helena': 27,
#  'brea-olinda': 27,
#  'carlos': 27,
#  'secondary': 27,
#  'arvin': 27,
#  'cox': 27,
#  'stone': 27,
#  'abc': 27,
#  'ukiah': 27,
#  'igo,': 27,
#  'bogus': 27,
#  'snowline': 27,
#  'rich-mar': 27,
#  'orick': 27,
#  'adelanto': 27,
#  'clovis': 27,
#  'herlong': 27,
#  'alamitos': 27,
#  'duarte': 27,
#  'ramona': 27,
#  'monroe': 27,
#  'grande': 27,
#  'pond': 27,
#  'culver': 27,
#  'heber': 27,
#  'covina-valley': 27,
#  'lucia': 27,
#  'ventura': 27,
#  'clear': 27,
#  'lucas': 27,
#  'pollock': 27,
#  'midway': 27,
#  'palmdale': 27,
#  'board': 27,
#  'haven': 27,
#  'trinidad': 27,
#  'fowler': 27,
#  'chatom': 27,
#  'gatos-saratoga': 27,
#  'pacheco': 27,
#  'memorial': 27,
#  'carson': 27,
#  'dehesa': 27,
#  'yucaipa-calimesa': 27,
#  'cutten': 27,
#  'centinela': 27,
#  'alexander': 27,
#  'menlo': 27,
#  'bragg': 27,
#  'auberry': 27,
#  'moraga': 27,
#  'coarsegold': 27,
#  'holtville': 27,
#  'bradley': 27,
#  'general': 27,
#  'menifee': 27,
#  'forks': 27,
#  'helm': 27,
#  'alps': 27,
#  'carmel': 27,
#  'castro': 27,
#  'caliente': 27,
#  'belridge': 27,
#  'trona': 27,
#  'glendale': 27,
#  'morgan': 27,
#  'rita': 27,
#  'standard': 27,
#  'outside': 27,
#  'monson-sultana': 27,
#  'somis': 27,
#  'richgrove': 27,
#  'cottonwood': 27,
#  'jackson': 27,
#  'keyes': 27,
#  'flournoy': 27,
#  'gilroy': 27,
#  'muroc': 27,
#  'woodville': 27,
#  'saugus': 27,
#  'sausalito': 27,
#  'howell': 27,
#  'barstow': 27,
#  'lewiston': 27,
#  'cardiff': 27,
#  'grass': 27,
#  'saddleback': 27,
#  'miguel': 27,
#  'jones': 27,
#  'sunnyvale': 27,
#  'madre': 27,
#  'kneeland': 27,
#  'three': 27,
#  'burlingame': 27,
#  'orinda': 27,
#  'mcswain': 27,
#  'luis': 27,
#  'idria': 27,
#  'visalia': 27,
#  'santee': 27,
#  'jacoby': 27,
#  'ballico-cressey': 27,
#  'clay': 27,
#  'fairfield-suisun': 27,
#  'china': 27,
#  'state': 27,
#  'hacienda': 27,
#  'chula': 27,
#  'pines': 27,
#  'fairview': 27,
#  'newport-mesa': 27,
#  'dunham': 27,
#  'bernardino': 27,
#  'roberts': 27,
#  'american': 27,
#  'orchard': 27,
#  'camptonville': 27,
#  'livingston': 27,
#  'meridian': 27,
#  'lode': 27,
#  'hayfork': 27,
#  'ridges': 27,
#  'milpitas': 27,
#  'maricopa': 27,
#  'glendora': 27,
#  'harmony': 27,
#  'swett': 27,
#  'oakley': 27,
#  'tehachapi': 27,
#  'placentia-yorba': 27,
#  'napa': 27,
#  'bravo-greeley': 27,
#  'manchester': 27,
#  'bassett': 27,
#  'corona-norco': 27,
#  'templeton': 27,
#  'kentfield': 27,
#  'tamalpais': 27,
#  'irvine': 27,
#  'lomitas': 27,
#  'pajaro': 27,
#  'antioch': 27,
#  'hornbrook': 27,
#  'hilt': 27,
#  'verdes': 27,
#  'bret': 27,
#  'gratton': 27,
#  'shandon': 27,
#  'alvina': 27,
#  'soledad-agua': 27,
#  'dixon': 27,
#  'dieguito': 27,
#  'trail': 27,
#  'moreno': 27,
#  'mariposa': 27,
#  'larkspur-corte': 27,
#  'franklin-mckinley': 27,
#  'lancaster': 27,
#  'klamath-trinity': 27,
#  'denair': 27,
#  'costa': 27,
#  'ceres': 27,
#  'luther': 27,
#  'placerville': 27,
#  'laytonville': 27,
#  'imperial': 27,
#  'centralia': 27,
#  'gerber': 27,
#  'geyserville': 27,
#  'lodi': 27,
#  'susanville': 27,
#  'martinez': 27,
#  'cow': 27,
#  'willits': 27,
#  'guasti': 27,
#  'phillips': 27,
#  'shores': 27,
#  'hart-ransom': 27,
#  'stanislaus': 27,
#  'bend': 27,
#  'kirkwood': 27,
#  'graves': 27,
#  'savanna': 27,
#  'mirada': 27,
#  'redlands': 27,
#  'bolinas-stinson': 27,
#  'gazelle': 27,
#  'quartz': 27,
#  'fieldbrook': 27,
#  'mckittrick': 27,
#  'gorman': 27,
#  'centro': 27,
#  'hydesville': 27,
#  'penryn': 27,
#  'williams': 27,
#  'brittan': 27,
#  'briggs': 27,
#  'banning': 27,
#  'montgomery': 27,
#  'angeles': 27,
#  'goleta': 27,
#  'hawthorne': 27,
#  'ducor': 27,
#  'princeton': 27,
#  'brentwood': 27,
#  'pierce': 27,
#  'dublin': 27,
#  'norte': 27,
#  'shaffer': 27,
#  'bayshore': 27,
#  ...}

# %%
# Get districts that might get filtered out
for i, row in DOE_data.iterrows():
  district = row['district']
  words = district.split()
  if words[0] in filler:
    print(district)
# Out:
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san leandro unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san lorenzo unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san ramon valley unified
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# san pasqual valley unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los angeles unified
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# los nietos
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel elementary
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san gabriel unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san marino unified
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san anselmo elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city elementary
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# san rafael city high
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# union joint elementary
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# los banos unified
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san antonio union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san ardo union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san lucas union elementary
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# san juan ridge union elementar
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# union hill elementary
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# los alamitos unified
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san joaquin elementary
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san jacinto unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san juan unified
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san benito high
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# san juan union elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# los flores elementary
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san bernardino city unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san diego unified
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san dieguito union high
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san marcos unified
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san pasqual union elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# san ysidro elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center union elementary
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# valley center-pauma unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san francisco unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san luis coastal unified
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san miguel joint union
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san bruno park elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san carlos elementary
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo union high
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# san mateo-foster city
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los alamos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los olivos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los altos elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos union elementary
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# los gatos-saratoga union high
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# san jose unified
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# union elementary
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# san lorenzo valley unified
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# valley home joint elementary
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# los molinos unified
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary
# valley oaks union elementary

# %%
matches = []

election_type = []

# Keep track of CEDA that were matched
CEDA_matched = {}

# Iterate through DOE data
for i, row in DOE_data.iterrows():
  year = row['year']
  county = row['county']
  district = row['district']
  candidates = list(CEDA_data[(CEDA_data['year'] == year) & (CEDA_data['cntyname'] == county)]['place'])

  # Dictionary for filtered: original name
  cand_dict = {}

  # Extract keywords in district name
  words = district.split()
  distr_word_list = [words[0]]
  for i in range(1, len(words)):
    if words[i] not in filler:
      distr_word_list.append(words[i])

  # Join keywords in district
  cleaned_distr = " ".join(distr_word_list)

  # Extract keywords in candidates
  filtered = []
  for candidate in candidates:
    words = candidate.split()
    cand_word_list = []

    # Extract keywords in candidates
    for i in range(len(words)):
      if words[i] not in filler:
        cand_word_list.append(words[i])

    # Join keywords in candidates
    cleaned_cand = ' '.join(cand_word_list)

    # Cleaned: original candidate
    cand_dict[cleaned_cand] = candidate

    # Consider candidate only if have common keyword
    for keyword in distr_word_list:
      if keyword in cand_word_list:
        filtered.append(cleaned_cand)
        break
  candidates = filtered

  if len(candidates) == 0:
    matches.append(['none', 0])
    election_type.append('none')
  else:
    match, score = process.extractOne(district, candidates, scorer=fuzz.token_set_ratio)
    matches.append([cand_dict[match], score])
    election_type.append(CEDA_data[(CEDA_data['year'] == year) & (CEDA_data['cntyname'] == county) & (CEDA_data['place'] == cand_dict[match])]['election_type'].item())
    if (cand_dict[match], year, county) in CEDA_matched:
      CEDA_matched[(cand_dict[match], year, county)].append(district)
    elif (cand_dict[match], year, county) not in CEDA_matched:
      CEDA_matched[(cand_dict[match], year, county)] = [district]

# %%
len(election_type)
# Out:
# 32022

# %%
# Append matches into columns on dataframe
DOE_data['match'] = [elem[0] for elem in matches]
DOE_data['score'] = [elem[1] for elem in matches]
DOE_data['election type'] = election_type
DOE_data
# Out:
#         county  year                  doctype              district  status  \
# 0      alameda  1996  Unified School District       alameda unified  Active
# 1      alameda  1997  Unified School District       alameda unified  Active
# 2      alameda  1998  Unified School District       alameda unified  Active
# 3      alameda  1999  Unified School District       alameda unified  Active
# 4      alameda  2000  Unified School District       alameda unified  Active
# ...        ...   ...                      ...                   ...     ...
# 32017     yuba  2018     High School District  wheatland union high  Active
# 32018     yuba  2019     High School District  wheatland union high  Active
# 32019     yuba  2020     High School District  wheatland union high  Active
# 32020     yuba  2021     High School District  wheatland union high  Active
# 32021     yuba  2022     High School District  wheatland union high  Active
#
#                              website     cds7   leaid  doc  \
# 0      http://www.alamedaunified.org   161119  601770   54
# 1      http://www.alamedaunified.org   161119  601770   54
# 2      http://www.alamedaunified.org   161119  601770   54
# 3      http://www.alamedaunified.org   161119  601770   54
# 4      http://www.alamedaunified.org   161119  601770   54
# ...                              ...      ...     ...  ...
# 32017   http://www.wheatlandhigh.org  5872769  642350   56
# 32018   http://www.wheatlandhigh.org  5872769  642350   56
# 32019   http://www.wheatlandhigh.org  5872769  642350   56
# 32020   http://www.wheatlandhigh.org  5872769  642350   56
# 32021   http://www.wheatlandhigh.org  5872769  642350   56
#
#                                  match  score election type
# 0           alameda board of education     64       Regular
# 1                                 none      0          none
# 2      alameda co. office of education     64       Regular
# 3                                 none      0          none
# 4                 alameda city unified    100       Regular
# ...                                ...    ...           ...
# 32017             wheatland elementary    100       Regular
# 32018                             none      0          none
# 32019             wheatland union high    100       Regular
# 32020                             none      0          none
# 32021                        wheatland    100       Regular
#
# [32022 rows x 12 columns]

# %%
# District : [Number of even year elections, total number of elections]
elections_2015 = {}

# Calculuate proportion of odd/even year elections before 2015
for i, row in DOE_data.iterrows():
  if row['match'] != 'none' and row['year'] <= 2015:
    if row['district'] in elections_2015:
      if row['year'] % 2 == 0:
        elections_2015[row['district']][0] += 1
      elections_2015[row['district']][1] += 1
    elif row['district'] not in elections_2015:
      if row['year'] % 2 == 0:
        elections_2015[row['district']] = [1, 1]
      else:
        elections_2015[row['district']] = [0, 1]

even_proportions = []
# Display proportions of even year elections before 2015
for i, row in DOE_data.iterrows():
  if row['district'] in elections_2015:
    even_proportion = elections_2015[row['district']][0]/elections_2015[row['district']][1]
    even_proportions.append(even_proportion)
  else:
    even_proportions.append(0)

DOE_data['even proportion before 2015'] = even_proportions

# %%
DOE_data.to_excel('/content/drive/MyDrive/Candidate Platforms and Endorsements/Data files/merged_DOE-CEDA.xlsx', index=False)

# %%
print('Number of entries that got matched in CEDA:', len(CEDA_matched))
print('Total number of CEDA entries:', len(CEDA_data))
# Out:
# Number of entries that got matched in CEDA: 6687
# Total number of CEDA entries: 7873

# %%
# Find which CEDA entries did get matched/not matched
matched = []
which_matched = []

counties = {}
multi_county = []
which_counties = []

# Get matches and counties
for i, row in CEDA_data.iterrows():
  county = row['cntyname']
  year = row['year']
  district = row['place']

  # Keep track of matches
  if (district, year, county) in CEDA_matched:
    matched.append(1)
    which_matched.append(CEDA_matched[(district, year, county)])
  else:
    matched.append(0)
    which_matched.append([])

  # Keep track of counties
  if district in counties:
    counties[district].add(county)
  else:
    counties[district] = {county}

# Populate district with their countries
for i, row in CEDA_data.iterrows():
  district = row['place']

  # Append counties
  if len(counties[district]) > 1:
    multi_county.append(1)
  else:
    multi_county.append(0)
  which_counties.append(counties[district])

# Add matched and county columns to CEDA data
CEDA_data['matched'] = matched
CEDA_data['matched to DOE'] = which_matched
CEDA_data['multi_county'] = multi_county
CEDA_data['which counties'] = which_counties

# %%
CEDA_data.to_excel('/content/drive/MyDrive/Candidate Platforms and Endorsements/Data files/Unique district-year elections from CEDA with DOE matches.xlsx', index=False)

# %%
CEDA_data[CEDA_data['matched to DOE']==0]
# Out:
# Empty DataFrame
# Columns: [cntyname, year, place, election_type, countyboard, coe, leaid, matched, matched to DOE, multi_county, which counties]
# Index: []

# %% [markdown]
# ## 1.3 Match from CEDA to DOE

# %%
# Load Department of Education data
DOE_data = pd.read_excel('/content/drive/My Drive/Candidate Platforms and Endorsements/Three files discussed 10-18-23/Base_File_from_State_Dept_Ed.xls')
DOE_data.head()
# Out:
#     County  Year                  DOCType         District  Status  \
# 0  Alameda  1996  Unified School District  Alameda Unified  Active
# 1  Alameda  1997  Unified School District  Alameda Unified  Active
# 2  Alameda  1998  Unified School District  Alameda Unified  Active
# 3  Alameda  1999  Unified School District  Alameda Unified  Active
# 4  Alameda  2000  Unified School District  Alameda Unified  Active
#
#                          WebSite    cds7   leaid  DOC
# 0  http://www.alamedaunified.org  161119  601770   54
# 1  http://www.alamedaunified.org  161119  601770   54
# 2  http://www.alamedaunified.org  161119  601770   54
# 3  http://www.alamedaunified.org  161119  601770   54
# 4  http://www.alamedaunified.org  161119  601770   54

# %%
# Load truncated unique district-year CEDA elections
CEDA_data = pd.read_excel('/content/drive/My Drive/Candidate Platforms and Endorsements/Three files discussed 10-18-23/All unique district-year elections from CEDA.xlsx')
CEDA_data.head()
# Out:
#   CNTYNAME  YEAR                       PLACE election_type  countyboard  coe  \
# 0  ALAMEDA  1996  ALAMEDA BOARD OF EDUCATION       Regular          NaN  NaN
# 1  ALAMEDA  2000        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
# 2  ALAMEDA  2004        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
# 3  ALAMEDA  2006        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
# 4  ALAMEDA  2010        ALAMEDA CITY UNIFIED       Regular          NaN  NaN
#
#    leaid
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
CEDA_data = CEDA_data[(CEDA_data['countyboard'] != 1) & (CEDA_data['coe'] != 1)]
CEDA_data = CEDA_data.drop(['countyboard', 'coe'], axis=1)

# %%
# Standardize column names
CEDA_data.columns = [x.lower() for x in CEDA_data.columns]
DOE_data.columns = [x.lower() for x in DOE_data.columns]

# Standardize strings
CEDA_data['cntyname'] = CEDA_data['cntyname'].str.lower()
CEDA_data['place'] = CEDA_data['place'].str.lower()

DOE_data['county'] = DOE_data['county'].str.lower()
DOE_data['district'] = DOE_data['district'].str.lower()

# %%
matches = []

# Keep matches in dictionary also
DOE_matched = {}

# Keep track of leaid
leaids = []

# Iterate through CEDA data
for i, row in CEDA_data.iterrows():
  year = row['year']
  county = row['cntyname']
  district = row['place']
  candidates = list(DOE_data[(DOE_data['year'] == year) & (DOE_data['county'] == county)]['district'])

  # Dictionary for filtered: original name
  cand_dict = {}

  # Extract keywords in district name
  words = district.split()
  distr_word_list = [words[0]]
  for i in range(1, len(words)):
    if words[i] not in filler:
      distr_word_list.append(words[i])

  # Join keywords in district
  cleaned_distr = " ".join(distr_word_list)

  # Extract keywords in candidates
  filtered = []
  for candidate in candidates:
    words = candidate.split()
    cand_word_list = []

    # Extract keywords in candidates
    for i in range(len(words)):
      if words[i] not in filler:
        cand_word_list.append(words[i])

    # Join keywords in candidates
    cleaned_cand = ' '.join(cand_word_list)

    # Cleaned: original candidate
    cand_dict[cleaned_cand] = candidate

    # Consider candidate only if have common keyword
    for keyword in distr_word_list:
      if keyword in cand_word_list:
        filtered.append(cleaned_cand)
        break
  candidates = filtered

  if len(candidates) == 0:
    matches.append(['none', 0])
    leaids.append(-1)
  else:
    match, score = process.extractOne(district, candidates, scorer=fuzz.token_set_ratio)
    matches.append([cand_dict[match], score])
    leaids.append(DOE_data[(DOE_data['year'] == year) & (DOE_data['county'] == county) & (DOE_data['district'] == cand_dict[match])]['leaid'].item())
    DOE_matched[(district, year, county)] = cand_dict[match]

# %%
# Append matches into columns  for elem in matches]
CEDA_data['match'] = [elem[0] for elem in matches]
CEDA_data['score'] = [elem[1] for elem in matches]
CEDA_data['multi_county'] = multi_county
CEDA_data['which counties'] = which_counties
CEDA_data['leaid'] = leaids
CEDA_data
# Out:
#      cntyname  year                         place election_type   leaid  \
# 0     alameda  1996    alameda board of education       Regular  601770
# 1     alameda  2000          alameda city unified       Regular  601770
# 2     alameda  2004          alameda city unified       Regular  601770
# 3     alameda  2006          alameda city unified       Regular  601770
# 4     alameda  2010          alameda city unified       Regular  601770
# ...       ...   ...                           ...           ...     ...
# 8357     yuba  2012          wheatland union high       Regular  642350
# 8358     yuba  2014          wheatland union high       Regular  642350
# 8359     yuba  2016          wheatland union high       Regular  642350
# 8360     yuba  2020          wheatland union high       Regular  642350
# 8361     yuba  1998  yuba co. office of education       Regular      -1
#
#                      match  score  multi_county which counties
# 0          alameda unified    100             0      {alameda}
# 1          alameda unified    100             0      {alameda}
# 2          alameda unified    100             0      {alameda}
# 3          alameda unified    100             0      {alameda}
# 4          alameda unified    100             0      {alameda}
# ...                    ...    ...           ...            ...
# 8357  wheatland union high    100             0         {yuba}
# 8358  wheatland union high    100             0         {yuba}
# 8359  wheatland union high    100             0         {yuba}
# 8360  wheatland union high    100             0         {yuba}
# 8361                  none      0             0         {yuba}
#
# [7873 rows x 9 columns]

# %%
CEDA_data.to_excel('/content/drive/MyDrive/Candidate Platforms and Endorsements/Data files/merged_CEDA-DOE.xlsx', index=False)

# %% [markdown]
# ## 1.4 Merge final candidate + CEDA districts with leaid data set

# %%
# Get CEDA data with leaid merged from DOE
district_data = pd.read_excel('/content/drive/MyDrive/Candidate Platforms and Endorsements/Data files/merged_CEDA-DOE.xlsx')
district_data
# Out:
#      cntyname  year                         place election_type   leaid  \
# 0     alameda  1996    alameda board of education       Regular  601770
# 1     alameda  2000          alameda city unified       Regular  601770
# 2     alameda  2004          alameda city unified       Regular  601770
# 3     alameda  2006          alameda city unified       Regular  601770
# 4     alameda  2010          alameda city unified       Regular  601770
# ...       ...   ...                           ...           ...     ...
# 7868     yuba  2012          wheatland union high       Regular  642350
# 7869     yuba  2014          wheatland union high       Regular  642350
# 7870     yuba  2016          wheatland union high       Regular  642350
# 7871     yuba  2020          wheatland union high       Regular  642350
# 7872     yuba  1998  yuba co. office of education       Regular      -1
#
#                      match  score  multi_county which counties
# 0          alameda unified    100             0    {'alameda'}
# 1          alameda unified    100             0    {'alameda'}
# 2          alameda unified    100             0    {'alameda'}
# 3          alameda unified    100             0    {'alameda'}
# 4          alameda unified    100             0    {'alameda'}
# ...                    ...    ...           ...            ...
# 7868  wheatland union high    100             0       {'yuba'}
# 7869  wheatland union high    100             0       {'yuba'}
# 7870  wheatland union high    100             0       {'yuba'}
# 7871  wheatland union high    100             0       {'yuba'}
# 7872                  none      0             0       {'yuba'}
#
# [7873 rows x 9 columns]

# %%
# Get CEDA data with candidates
cand_data = pd.read_excel('/content/drive/MyDrive/Candidate Platforms and Endorsements/Data files/appended_CEDA_w_priorities.xlsx')

# Lowercase everything
cand_data['cntyname'] = cand_data['cntyname'].str.lower()
cand_data['place'] = cand_data['place'].str.lower()
cand_data['last'] = cand_data['last'].str.lower()
cand_data['first'] = cand_data['first'].str.lower()
cand_data['baldesig'] = cand_data['baldesig'].str.lower()
cand_data['incumb'] = cand_data['incumb'].str.lower()

cand_data
# Out:
#       cntyname  year                            place              last  \
# 0      alameda  1996       alameda board of education            greely
# 1      alameda  1996       alameda board of education          guenther
# 2      alameda  1996       alameda board of education              huie
# 3      alameda  1996       alameda board of education         linebarry
# 4      alameda  1996       alameda board of education           mcmahon
# ...        ...   ...                              ...               ...
# 45179     yuba  2016  yuba county office of education            hastey
# 45180     yuba  2016  yuba county office of education            bishop
# 45181     yuba  2016  yuba county office of education            dawson
# 45182     yuba  2020  yuba county office of education  myerpeter-newman
# 45183     yuba  2020  yuba county office of education            hastey
#
#                  first                           baldesig  \
# 0             gail ann               incumbent and parent
# 1           barbara m.       parent/case manager/advocate
# 2                  sam  grandparent/computer professional
# 3      claude s. butch              management consultant
# 4              michael                    systems analyst
# ...                ...                                ...
# 45179          desiree               small business owner
# 45180            tracy       youth program representative
# 45181     emily torres                          incumbent
# 45182             anna                    retired teacher
# 45183          desiree                          incumbent
#
#                     office incumb  co#  multi_candid  multi_co     raceid  \
# 0             BOARD MEMBER      y    1     199603002         0  199600920
# 1             BOARD MEMBER      n    1     199603003         0  199600920
# 2             BOARD MEMBER      n    1     199603004         0  199600920
# 3             BOARD MEMBER      n    1     199603005         0  199600920
# 4             BOARD MEMBER      n    1     199603006         0  199600920
# ...                    ...    ...  ...           ...       ...        ...
# 45179  SCHOOL BOARD MEMBER      n   58     201605067         0       1630
# 45180  SCHOOL BOARD MEMBER      n   58     201605068         0       1630
# 45181  SCHOOL BOARD MEMBER      y   58     201605069         0       1630
# 45182  SCHOOL BOARD MEMBER      n   58     202006601         0       2209
# 45183  SCHOOL BOARD MEMBER      y   58     202006600         0       2209
#
#         percent  elected  newelected  \
# 0      0.208098        1           1
# 1      0.180278        1           1
# 2      0.147389        2           2
# 3      0.067111        2           2
# 4      0.099790        2           2
# ...         ...      ...         ...
# 45179  0.466427        1           1
# 45180  0.358610        2           2
# 45181  0.174963        2           2
# 45182  0.461054        2           2
# 45183  0.538946        1           1
#
#                                               priorities
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Securing sufficient and stable funding for Ala...
# ...                                                  ...
# 45179                                                NaN
# 45180                                                NaN
# 45181                                                NaN
# 45182                                                NaN
# 45183                                                NaN
#
# [45184 rows x 16 columns]

# %%
# Get all (year, county, district) in districts data
districts = set()

for i, row in district_data.iterrows():
  districts.add((row['year'], row['cntyname'], row['place']))

# Only get candidates that having matching (year, county, district) in CEDA districts data
for i, row in cand_data.iterrows():
  if (row['year'], row['cntyname'], row['place']) not in districts:
    cand_data = cand_data.drop(i)

cand_data
# Out:
#       cntyname  year                         place              last  \
# 0      alameda  1996    alameda board of education            greely
# 1      alameda  1996    alameda board of education          guenther
# 2      alameda  1996    alameda board of education              huie
# 3      alameda  1996    alameda board of education         linebarry
# 4      alameda  1996    alameda board of education           mcmahon
# ...        ...   ...                           ...               ...
# 45162     yuba  2020          wheatland union high            forest
# 45163     yuba  2020          wheatland union high            mchugh
# 45164     yuba  2020          wheatland union high             meder
# 45165     yuba  1998  yuba co. office of education  anderson-chappel
# 45166     yuba  1998  yuba co. office of education         landerman
#
#                  first                           baldesig  \
# 0             gail ann               incumbent and parent
# 1           barbara m.       parent/case manager/advocate
# 2                  sam  grandparent/computer professional
# 3      claude s. butch              management consultant
# 4              michael                    systems analyst
# ...                ...                                ...
# 45162             greg              no ballot designation
# 45163          brendan              no ballot designation
# 45164         shawndel                   registered nurse
# 45165             cleo                  technical support
# 45166         donna m.                          incumbent
#
#                     office incumb  co#  multi_candid  multi_co     raceid  \
# 0             BOARD MEMBER      y    1     199603002         0  199600920
# 1             BOARD MEMBER      n    1     199603003         0  199600920
# 2             BOARD MEMBER      n    1     199603004         0  199600920
# 3             BOARD MEMBER      n    1     199603005         0  199600920
# 4             BOARD MEMBER      n    1     199603006         0  199600920
# ...                    ...    ...  ...           ...       ...        ...
# 45162  SCHOOL BOARD MEMBER      n   58     202006597         0       2208
# 45163  SCHOOL BOARD MEMBER      n   58     202006598         0       2208
# 45164  SCHOOL BOARD MEMBER      y   58     202006599         0       2208
# 45165  SCHOOL BOARD MEMBER      n   58     199805181         0  199801741
# 45166  SCHOOL BOARD MEMBER      y   58     199805182         0  199801741
#
#         percent  elected  newelected  \
# 0      0.208098        1           1
# 1      0.180278        1           1
# 2      0.147389        2           2
# 3      0.067111        2           2
# 4      0.099790        2           2
# ...         ...      ...         ...
# 45162  0.260012        1           1
# 45163  0.205447        2           2
# 45164  0.317681        1           1
# 45165  0.321562        2           2
# 45166  0.668467        1           1
#
#                                               priorities
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Securing sufficient and stable funding for Ala...
# ...                                                  ...
# 45162                                                NaN
# 45163                                                NaN
# 45164                                                NaN
# 45165                                                NaN
# 45166                                                NaN
#
# [37730 rows x 16 columns]

# %%
# Get leaid into candidates from district
leaids = []

# Get matches into candidates from district
matches = []

for i, row in cand_data.iterrows():
  year = row['year']
  county = row['cntyname']
  district = row['place']

  leaids.append(district_data[(district_data['year'] == year) & (district_data['cntyname'] == county) & (district_data['place'] == district)]['leaid'].item())
  matches.append(district_data[(district_data['year'] == year) & (district_data['cntyname'] == county) & (district_data['place'] == district)]['match'].item())

cand_data['leaid'] = leaids
cand_data['matches'] = matches

# %%
cand_data
# Out:
#       cntyname  year                         place              last  \
# 0      alameda  1996    alameda board of education            greely
# 1      alameda  1996    alameda board of education          guenther
# 2      alameda  1996    alameda board of education              huie
# 3      alameda  1996    alameda board of education         linebarry
# 4      alameda  1996    alameda board of education           mcmahon
# ...        ...   ...                           ...               ...
# 45162     yuba  2020          wheatland union high            forest
# 45163     yuba  2020          wheatland union high            mchugh
# 45164     yuba  2020          wheatland union high             meder
# 45165     yuba  1998  yuba co. office of education  anderson-chappel
# 45166     yuba  1998  yuba co. office of education         landerman
#
#                  first                           baldesig  \
# 0             gail ann               incumbent and parent
# 1           barbara m.       parent/case manager/advocate
# 2                  sam  grandparent/computer professional
# 3      claude s. butch              management consultant
# 4              michael                    systems analyst
# ...                ...                                ...
# 45162             greg              no ballot designation
# 45163          brendan              no ballot designation
# 45164         shawndel                   registered nurse
# 45165             cleo                  technical support
# 45166         donna m.                          incumbent
#
#                     office incumb  co#  multi_candid  multi_co     raceid  \
# 0             BOARD MEMBER      y    1     199603002         0  199600920
# 1             BOARD MEMBER      n    1     199603003         0  199600920
# 2             BOARD MEMBER      n    1     199603004         0  199600920
# 3             BOARD MEMBER      n    1     199603005         0  199600920
# 4             BOARD MEMBER      n    1     199603006         0  199600920
# ...                    ...    ...  ...           ...       ...        ...
# 45162  SCHOOL BOARD MEMBER      n   58     202006597         0       2208
# 45163  SCHOOL BOARD MEMBER      n   58     202006598         0       2208
# 45164  SCHOOL BOARD MEMBER      y   58     202006599         0       2208
# 45165  SCHOOL BOARD MEMBER      n   58     199805181         0  199801741
# 45166  SCHOOL BOARD MEMBER      y   58     199805182         0  199801741
#
#         percent  elected  newelected  \
# 0      0.208098        1           1
# 1      0.180278        1           1
# 2      0.147389        2           2
# 3      0.067111        2           2
# 4      0.099790        2           2
# ...         ...      ...         ...
# 45162  0.260012        1           1
# 45163  0.205447        2           2
# 45164  0.317681        1           1
# 45165  0.321562        2           2
# 45166  0.668467        1           1
#
#                                               priorities   leaid  \
# 0                                                    NaN  601770
# 1                                                    NaN  601770
# 2                                                    NaN  601770
# 3                                                    NaN  601770
# 4      Securing sufficient and stable funding for Ala...  601770
# ...                                                  ...     ...
# 45162                                                NaN  642350
# 45163                                                NaN  642350
# 45164                                                NaN  642350
# 45165                                                NaN      -1
# 45166                                                NaN      -1
#
#                     matches
# 0           alameda unified
# 1           alameda unified
# 2           alameda unified
# 3           alameda unified
# 4           alameda unified
# ...                     ...
# 45162  wheatland union high
# 45163  wheatland union high
# 45164  wheatland union high
# 45165                  none
# 45166                  none
#
# [37730 rows x 18 columns]

# %%
cand_data.to_excel('/content/drive/MyDrive/Candidate Platforms and Endorsements/Data files/final_candidate_data.xlsx', index=False)

# %% [markdown]
# # 1.5 Merge School District Data from Urban Institute API

# %%
'''ccd_columns = ['lea_name', 'fips', 'state_leaid', 'street_mailing', 'city_mailing', 'state_mailing', 'zip_mailing', 'zip4_mailing', 'street_location', 'city_location', 'state_location', 'zip_location', 'zip4_location', 'phone', 'latitude', 'longitude', 'urban_centric_locale', 'cbsa', 'cbsa_type', 'csa', 'cmsa', 'necta', 'county_code', 'county_name', 'congress_district_id', 'bureau_indian_education', 'supervisory_union_number', 'agency_type', 'agency_level', 'boundary_change_indicator', 'agency_charter_indicator', 'lowest_grade_offered', 'highest_grade_offered', 'number_of_schools', 'enrollment', 'spec_ed_students', 'english_language_learners', 'migrant_students', 'teachers_prek_fte', 'teachers_kindergarten_fte', 'teachers_elementary_fte', 'teachers_secondary_fte', 'teachers_ungraded_fte', 'teachers_total_fte', 'instructional_aides_fte', 'coordinators_fte', 'guidance_counselors_elem_fte', 'guidance_counselors_sec_fte', 'guidance_counselors_other_fte', 'guidance_counselors_total_fte', 'librarian_specialists_fte', 'librarian_support_staff_fte', 'lea_administrators_fte', 'lea_admin_support_staff_fte', 'school_administrators_fte', 'school_admin_support_staff_fte', 'support_staff_students_fte', 'support_staff_other_fte', 'staff_total_fte', 'lea_staff_total_fte', 'other_staff_fte', 'school_staff_total_fte', 'school_counselors_fte', 'state_leg_district_lower', 'state_leg_district_upper', 'school_psychologists_fte', 'support_staff_stu_wo_psych_fte']
saipe_columns = ['district_id', 'district_name', 'est_population_total', 'est_population_5_17', 'est_population_5_17_poverty', 'fips', 'est_population_5_17_poverty_pct', 'est_population_5_17_pct']

for col in ccd_columns:
  cand_data[col] = None  # You can assign default values or None if needed

for col in saipe_columns:
  cand_data[col] = None  # You can assign default values or None if needed

cand_data
'''
# Out:
#       cntyname  year                         place              last  \
# 0      alameda  1996    alameda board of education            greely
# 1      alameda  1996    alameda board of education          guenther
# 2      alameda  1996    alameda board of education              huie
# 3      alameda  1996    alameda board of education         linebarry
# 4      alameda  1996    alameda board of education           mcmahon
# ...        ...   ...                           ...               ...
# 45162     yuba  2020          wheatland union high            forest
# 45163     yuba  2020          wheatland union high            mchugh
# 45164     yuba  2020          wheatland union high             meder
# 45165     yuba  1998  yuba co. office of education  anderson-chappel
# 45166     yuba  1998  yuba co. office of education         landerman
#
#                  first                           baldesig  \
# 0             gail ann               incumbent and parent
# 1           barbara m.       parent/case manager/advocate
# 2                  sam  grandparent/computer professional
# 3      claude s. butch              management consultant
# 4              michael                    systems analyst
# ...                ...                                ...
# 45162             greg              no ballot designation
# 45163          brendan              no ballot designation
# 45164         shawndel                   registered nurse
# 45165             cleo                  technical support
# 45166         donna m.                          incumbent
#
#                     office incumb  co#  multi_candid  ...  \
# 0             BOARD MEMBER      y    1     199603002  ...
# 1             BOARD MEMBER      n    1     199603003  ...
# 2             BOARD MEMBER      n    1     199603004  ...
# 3             BOARD MEMBER      n    1     199603005  ...
# 4             BOARD MEMBER      n    1     199603006  ...
# ...                    ...    ...  ...           ...  ...
# 45162  SCHOOL BOARD MEMBER      n   58     202006597  ...
# 45163  SCHOOL BOARD MEMBER      n   58     202006598  ...
# 45164  SCHOOL BOARD MEMBER      y   58     202006599  ...
# 45165  SCHOOL BOARD MEMBER      n   58     199805181  ...
# 45166  SCHOOL BOARD MEMBER      y   58     199805182  ...
#
#        state_leg_district_upper  school_psychologists_fte  \
# 0                          None                      None
# 1                          None                      None
# 2                          None                      None
# 3                          None                      None
# 4                          None                      None
# ...                         ...                       ...
# 45162                      None                      None
# 45163                      None                      None
# 45164                      None                      None
# 45165                      None                      None
# 45166                      None                      None
#
#        support_staff_stu_wo_psych_fte  district_id  district_name  \
# 0                                None         None           None
# 1                                None         None           None
# 2                                None         None           None
# 3                                None         None           None
# 4                                None         None           None
# ...                               ...          ...            ...
# 45162                            None         None           None
# 45163                            None         None           None
# 45164                            None         None           None
# 45165                            None         None           None
# 45166                            None         None           None
#
#       est_population_total est_population_5_17 est_population_5_17_poverty  \
# 0                     None                None                        None
# 1                     None                None                        None
# 2                     None                None                        None
# 3                     None                None                        None
# 4                     None                None                        None
# ...                    ...                 ...                         ...
# 45162                 None                None                        None
# 45163                 None                None                        None
# 45164                 None                None                        None
# 45165                 None                None                        None
# 45166                 None                None                        None
#
#       est_population_5_17_poverty_pct est_population_5_17_pct
# 0                                None                    None
# 1                                None                    None
# 2                                None                    None
# 3                                None                    None
# 4                                None                    None
# ...                               ...                     ...
# 45162                            None                    None
# 45163                            None                    None
# 45164                            None                    None
# 45165                            None                    None
# 45166                            None                    None
#
# [37730 rows x 92 columns]

# %%
'''
from pprint import pprint
import requests

ccd_url = "https://educationdata.urban.org/api/v1/school-districts/ccd/directory/"
saipe_url = "https://educationdata.urban.org/api/v1/school-districts/saipe/"
keys_to_remove = ['year', 'leaid']


i = 0
for index, row in cand_data.iterrows():
  leaid = "0" + str(row['leaid'])
  leaid = "123123312312"
  year = str(row['year'])
  curr_ccd_url = ccd_url + year
  curr_saipe_url = saipe_url + year

  payload = {
    "leaid": leaid
  }

  # Pass filters into API request

  ccd_response = requests.get(curr_ccd_url, params=payload).json()['results']
  saipe_response = requests.get(curr_saipe_url, params=payload).json()['results']

  if len(saipe_response) != 0:
    saipe_response = saipe_response[0]
    for key in keys_to_remove:
      saipe_response.pop(key, None)

      # add the json data to the cand_data df
      for key, value in saipe_response.items():
        row[key] = value


  if len(ccd_response) != 0:
    print("Found ccd data")
    print(ccd_response)
    ccd_response = ccd_response[0]
    for key in keys_to_remove:
      ccd_response.pop(key, None)

      # add the json data to the cand_data df
      for key, value in ccd_response.items():
        row[key] = value
  i += 1
  if i % 100 == 0: break


cand_data
'''
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-d9825f4dbf5f> in <cell line: 10>()
#      21   # Pass filters into API request
#      22
# ---> 23   ccd_response = requests.get(curr_ccd_url, params=payload).json()['results']
#      24   saipe_response = requests.get(curr_saipe_url, params=payload).json()['results']
#      25
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466             # Trigger any extra validation we need to do.
#     467             try:
# --> 468                 self._validate_conn(conn)
#     469             except (SocketTimeout, BaseSSLError) as e:
#     470                 self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1095         # Force connect early to allow us to validate the connection.
#    1096         if conn.is_closed:
# -> 1097             conn.connect()
#    1098
#    1099         if not conn.is_verified:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     640             )
#     641
# --> 642         sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643             sock=sock,
#     644             cert_reqs=self.cert_reqs,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     781             server_hostname = normalized
#     782
# --> 783     ssl_sock = ssl_wrap_socket(
#     784         sock=sock,
#     785         keyfile=key_file,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     444     if ca_certs or ca_cert_dir or ca_cert_data:
#     445         try:
# --> 446             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     447         except OSError as e:
#     448             raise SSLError(e) from e
#
# KeyboardInterrupt:

# %% [markdown]
# # 1.6 Append priorities features into final dataset

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (0.18.0)

# %%
cand_labels = pd.read_excel('/content/drive/My Drive/Candidate Platforms and Endorsements/Data files/Priorities_Latest_10-10-23_with_Ten_Topics.xlsx')

# %%
# Drop NaN
cand_labels = cand_labels.dropna()

# Standardize columns
cand_labels.columns = [x.lower() for x in cand_labels.columns]

# Lowercase year and name
cand_labels['candidate_name'] = cand_labels['candidate_name'].str.lower()
cand_labels['districtname'] = cand_labels['districtname'].str.lower()
cand_labels['county'] = cand_labels['county'].str.lower()
cand_labels['priority'] = cand_labels['priority'].str.lower()
# Out:
# <ipython-input-9-e5f9423795ac>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cand_labels['candidate_name'] = cand_labels['candidate_name'].str.lower()
# <ipython-input-9-e5f9423795ac>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cand_labels['districtname'] = cand_labels['districtname'].str.lower()
# <ipython-input-9-e5f9423795ac>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cand_labels['county'] = cand_labels['county'].str.lower()
# <ipython-input-9-e5f9423795ac>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cand_labels['priority'] = cand_labels['priority'].str.lower()

# %%
cand_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30154 entries, 0 to 30179
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            30154 non-null  int64
#  1   candidate_name  30154 non-null  object
#  2   districtname    30154 non-null  object
#  3   county          30154 non-null  object
#  4   priority        30154 non-null  object
#  5   topic_0         30154 non-null  float64
#  6   topic_1         30154 non-null  float64
#  7   topic_2         30154 non-null  float64
#  8   topic_3         30154 non-null  float64
#  9   topic_4         30154 non-null  float64
#  10  topic_5         30154 non-null  float64
#  11  topic_6         30154 non-null  float64
#  12  topic_7         30154 non-null  float64
#  13  topic_8         30154 non-null  float64
#  14  topic_9         30154 non-null  float64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 3.7+ MB

# %%
CEDA_priorities = pd.read_excel('/content/drive/My Drive/Candidate Platforms and Endorsements/Data files/merged_final_candidate_data.xlsx')

# %%
cand_labels
# Out:
#        year      candidate_name  \
# 0      1997      suzan mannisto
# 1      1997      suzan mannisto
# 2      1997      suzan mannisto
# 3      1997    catherine bonnar
# 4      1997    catherine bonnar
# ...     ...                 ...
# 30175  2022  rogelio villagrana
# 30176  2022  rogelio villagrana
# 30177  2022   catherine saeturn
# 30178  2022   catherine saeturn
# 30179  2022   catherine saeturn
#
#                                             districtname     county  \
# 0      belmont-redwood shores elementary school district  san mateo
# 1      belmont-redwood shores elementary school district  san mateo
# 2      belmont-redwood shores elementary school district  san mateo
# 3      belmont-redwood shores elementary school district  san mateo
# 4      belmont-redwood shores elementary school district  san mateo
# ...                                                  ...        ...
# 30175  trustee area 7, woodland joint unified school ...       yolo
# 30176  trustee area 7, woodland joint unified school ...       yolo
# 30177  trustee area 7, woodland joint unified school ...       yolo
# 30178  trustee area 7, woodland joint unified school ...       yolo
# 30179  trustee area 7, woodland joint unified school ...       yolo
#
#                                                 priority   topic_0   topic_1  \
# 0      manage growth of district as flow of students ...  0.037900  0.046479
# 1      maintain high quality of curricula with input ...  0.146378  0.105995
# 2      encourage individual "personality" of each sch...  0.160340  0.105995
# 3      expand sandpiper school to a full k-5th grade ...  0.037942  0.111998
# 4      wisely budget $12 million bond revenue with co...  0.031591  0.204871
# ...                                                  ...       ...       ...
# 30175  student involvement in the decision making pro...  0.062719  0.027904
# 30176  maximize community resources to increase suppo...  0.022754  0.067863
# 30177  prioritize communication and transparency by a...  0.043718  0.130405
# 30178  set goals and create opportunities for our com...  0.043718  0.053615
# 30179  ensure we are following all policies such as p...  0.051650  0.063343
#
#         topic_2   topic_3   topic_4   topic_5   topic_6   topic_7   topic_8  \
# 0      0.028348  0.044122  0.027025  0.132960  0.168425  0.231308  0.033500
# 1      0.026576  0.041366  0.025336  0.076238  0.220314  0.279256  0.031407
# 2      0.026577  0.041367  0.092849  0.181995  0.157896  0.154439  0.031407
# 3      0.028379  0.044171  0.027054  0.199776  0.101958  0.231547  0.166846
# 4      0.023629  0.092274  0.022881  0.055342  0.251300  0.137309  0.083413
# ...         ...       ...       ...       ...       ...       ...       ...
# 30175  0.017018  0.026489  0.016224  0.119759  0.396327  0.243302  0.020111
# 30176  0.017019  0.227361  0.016225  0.159773  0.179999  0.178841  0.060029
# 30177  0.032699  0.050896  0.035209  0.076586  0.117480  0.339581  0.115432
# 30178  0.109487  0.050896  0.031173  0.076585  0.208120  0.329771  0.038642
# 30179  0.038632  0.060131  0.127565  0.181218  0.138797  0.224494  0.045654
#
#         topic_9
# 0      0.249934
# 1      0.047134
# 2      0.047135
# 3      0.050330
# 4      0.097390
# ...         ...
# 30175  0.070147
# 30176  0.070135
# 30177  0.057993
# 30178  0.057992
# 30179  0.068515
#
# [30154 rows x 15 columns]

# %%
CEDA_priorities
# Out:
#       cntyname  year                         place              last  \
# 0      alameda  1996    alameda board of education            greely
# 1      alameda  1996    alameda board of education          guenther
# 2      alameda  1996    alameda board of education              huie
# 3      alameda  1996    alameda board of education         linebarry
# 4      alameda  1996    alameda board of education           mcmahon
# ...        ...   ...                           ...               ...
# 37725     yuba  2020          wheatland union high            forest
# 37726     yuba  2020          wheatland union high            mchugh
# 37727     yuba  2020          wheatland union high             meder
# 37728     yuba  1998  yuba co. office of education  anderson-chappel
# 37729     yuba  1998  yuba co. office of education         landerman
#
#                  first                           baldesig  \
# 0             gail ann               incumbent and parent
# 1           barbara m.       parent/case manager/advocate
# 2                  sam  grandparent/computer professional
# 3      claude s. butch              management consultant
# 4              michael                    systems analyst
# ...                ...                                ...
# 37725             greg              no ballot designation
# 37726          brendan              no ballot designation
# 37727         shawndel                   registered nurse
# 37728             cleo                  technical support
# 37729         donna m.                          incumbent
#
#                     office incumb  co#  multi_candid  ...  \
# 0             BOARD MEMBER      y    1     199603002  ...
# 1             BOARD MEMBER      n    1     199603003  ...
# 2             BOARD MEMBER      n    1     199603004  ...
# 3             BOARD MEMBER      n    1     199603005  ...
# 4             BOARD MEMBER      n    1     199603006  ...
# ...                    ...    ...  ...           ...  ...
# 37725  SCHOOL BOARD MEMBER      n   58     202006597  ...
# 37726  SCHOOL BOARD MEMBER      n   58     202006598  ...
# 37727  SCHOOL BOARD MEMBER      y   58     202006599  ...
# 37728  SCHOOL BOARD MEMBER      n   58     199805181  ...
# 37729  SCHOOL BOARD MEMBER      y   58     199805182  ...
#
#        state_leg_district_upper  school_psychologists_fte  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 37725                    6004.0                       0.0
# 37726                    6004.0                       0.0
# 37727                    6004.0                       0.0
# 37728                       NaN                       NaN
# 37729                       NaN                       NaN
#
#        support_staff_stu_wo_psych_fte  district_id  \
# 0                                 NaN          NaN
# 1                                 NaN          NaN
# 2                                 NaN          NaN
# 3                                 NaN          NaN
# 4                                 NaN          NaN
# ...                               ...          ...
# 37725                             1.0      42350.0
# 37726                             1.0      42350.0
# 37727                             1.0      42350.0
# 37728                             NaN          NaN
# 37729                             NaN          NaN
#
#                               district_name est_population_total  \
# 0                                       NaN                  NaN
# 1                                       NaN                  NaN
# 2                                       NaN                  NaN
# 3                                       NaN                  NaN
# 4                                       NaN                  NaN
# ...                                     ...                  ...
# 37725  Wheatland Union High School District              14717.0
# 37726  Wheatland Union High School District              14717.0
# 37727  Wheatland Union High School District              14717.0
# 37728                                   NaN                  NaN
# 37729                                   NaN                  NaN
#
#       est_population_5_17 est_population_5_17_poverty  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
# ...                   ...                         ...
# 37725               832.0                        60.0
# 37726               832.0                        60.0
# 37727               832.0                        60.0
# 37728                 NaN                         NaN
# 37729                 NaN                         NaN
#
#       est_population_5_17_poverty_pct  est_population_5_17_pct
# 0                                 NaN                      NaN
# 1                                 NaN                      NaN
# 2                                 NaN                      NaN
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# ...                               ...                      ...
# 37725                        0.072115                 0.056533
# 37726                        0.072115                 0.056533
# 37727                        0.072115                 0.056533
# 37728                             NaN                      NaN
# 37729                             NaN                      NaN
#
# [37730 rows x 92 columns]

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def fuzzy_match_and_merge(candidate_data, ceda_data):
    # Function to find the best fuzzy match for each candidate in the CEDA dataset
    def find_best_match(name, candidates):
        match, score,_ = process.extractOne(name, candidates, scorer=fuzz.token_set_ratio)
        return match, score

    # Create a dictionary of candidate names as keys and their priorities as values
    name_to_labels = {}
    name_to_score = {}

    num_added = 0
    num_read = 0

    for i, row in ceda_data.iterrows():
        ceda_name = f"{row['first']} {row['last']}"
        ceda_year = row['year']
        ceda_county = row['cntyname']

        # Filter candidate data to the same year and county
        year_county_matched_candidates = candidate_data[(candidate_data['year'] == ceda_year) & (candidate_data['county'] == ceda_county)]

        if not year_county_matched_candidates.empty:
            match, score = find_best_match(ceda_name, year_county_matched_candidates['candidate_name'])
            if score > 80:
                # Found a match with a high enough score, add to dictionary
                matched_rows = year_county_matched_candidates.loc[
                    year_county_matched_candidates['candidate_name'] == match
                ]

                for topic_col in ['topic_0', 'topic_1', 'topic_2', 'topic_3', 'topic_4', 'topic_5', 'topic_6', 'topic_7', 'topic_8', 'topic_9']:
                  topic_vals = matched_rows[topic_col].values
                  ceda_data.at[i, topic_col] = np.mean(topic_vals)

                  if (ceda_name, ceda_year, ceda_county) in name_to_labels:
                    name_to_labels[(ceda_name, ceda_year, ceda_county)].append(np.mean(topic_vals))
                  else:
                    name_to_labels[(ceda_name, ceda_year, ceda_county)] = [np.mean(topic_vals)]

                name_to_score[ceda_name] = score  # Store the score
                num_added += 1

                #if score != 100:
                #  print("Name in CEDA data: ", ceda_name)
                #  print("Matched name from candidate data: ", match)
                #  print("Year: ", ceda_year)
                #  print("Score was: ", score)
                #  print(row)

        num_read += 1

        #if num_read % 100 == 0:
        #  print(num_added , "samples have been matched out of ", num_read)

    return ceda_data, name_to_labels, name_to_score

# %%
CEDA_priorities, name_to_labels, name_to_score = fuzzy_match_and_merge(cand_labels, CEDA_priorities)

# Truncate keys where there are duplicates in CEDA (ie. Forrest Gee registered twice in 2001 Alameda for some reason)
for key in name_to_labels:
  if len(name_to_labels[key]) > 10:
    name_to_labels[key] = name_to_labels[key][:10]

# %%
'''
    # Create a new 'score' column in the CEDA dataset
    ceda_data['score'] = ceda_data.apply(
        lambda row: name_to_score.get(f"{row['first']} {row['last']}", None), axis=1
    )

    # Create 10 topic columns
    ceda_data = pd.concat([ceda_data, pd.DataFrame(name_to_labels)], axis=1)
'''

# %%
CEDA_priorities.to_excel('/content/drive/MyDrive/Candidate Platforms and Endorsements/Data files/featurized_CEDA_priorities.xlsx', index=False)
